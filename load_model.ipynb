# %%
import torch

# %%
loaded_data = torch.load('final_model.pt')
print(type(loaded_data))

print(loaded_data.keys())
# Out:
# <class 'collections.OrderedDict'>
# odict_keys(['lin1.weight', 'lin1.bias', 'lin2.weight', 'lin2.bias', 'lin3.weight', 'lin3.bias'])
